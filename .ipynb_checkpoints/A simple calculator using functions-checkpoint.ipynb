# %% [markdown]
# ## A simple calculator using functions
#
# 1) Read code and discuss - ask questions!
#
# 2) Comment code
#
# 3) Extend the calculator with 5 more functions

# %%
def mainMenu():
    #main fuction contains the different options
    validChoices = ["A", "S", "M", "D", "E"]
    valid = False
    while valid == False:
        print("A)dd numbers")
        print("S)ubtract numbers")
        print("M)ultiply numbers")
        print("D)ivide numbers")
        print("E)ven number checker")
        choice = (input("\nChoose your option")).upper()
        if choice not in validChoices:
            print("\nSorry that is not a valid menu choice ")
        else:
            valid= True
    #choice is returned to allow the variable choice to be used
    return choice
    

def enterNumber():
    valid = False
    while not valid:
        try:
            x=int(input("\nEnter the number "))
            valid=True
        except ValueError:
            print("That was not a valid number. Please try again")
    
    return x


def add(x,y):
    return x+y

def subtract(x,y):
    return x-y

def multiply(x,y):
    return x*y

def divide(x,y):
    return x/y

def evenNumber(x,y):
    checkEvenx = x % 2
    checkEveny = y % 2
    if checkEvenx == 0:
        answerx = (x, " is Even")
    else:
        answerx = (x, " is Odd")
    if checkEveny == 0:
        answerx = (y, " is Even")
    else:
        answerx = (y, " is Odd")
    return answerx
    return answery


#main program starts here
print("welcome to my calculator")
again = "y"
while again == "y":
    userChoice = mainMenu()
    if userChoice == "A":
        answer = add(enterNumber(), enterNumber())
    elif userChoice == "S":
        answer = subtract(enterNumber(), enterNumber())
    elif userChoice == "M":
        answer = multiply(enterNumber(), enterNumber())
    elif userChoice == "D":
        answer = divide(enterNumber(), enterNumber())
    elif userChoice == "E":
        answer = evenNumber(enterNumber(), enterNumber())
    else:
        print("error - we should never get here")
    
    if userChoice == "A" or userChoice == "S" or userChoice == "M" or userChoice == "D":
        print("\nthe answer from your calcaulation is = "+str(answer))
    else:
        print("")
# Out:
# welcome to my calculator
# A)dd numbers
# S)ubtract numbers
# M)ultiply numbers
# D)ivide numbers
# E)ven number checker
#
# Choose your optionE
#
# Enter the first number1
#
# Enter the first number2
#
# A)dd numbers
# S)ubtract numbers
# M)ultiply numbers
# D)ivide numbers
# E)ven number checker
